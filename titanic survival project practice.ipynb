# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\RITVIK BHARDWAJ\Downloads\titanic_train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
print('No. of Rows :',df.shape[0])
print('No. of Columns :',df.shape[1])
pd.set_option('display.max_columns',None)
df.head()
# Out:
# No. of Rows : 891
# No. of Columns : 12
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], float64: ['Age', 'Fare'], object: ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']}

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Checking for presense of whitespaces, '?','null'

# %%
df.isin([' ','?','-','null','NA']).sum().any()
# Out:
# False

# %%
#Missing Value check

# %%
plt.figure(figsize = (8,6))
sns.heatmap(df.isnull(),cmap = 'cool_r')
plt.show()

# %%
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#              Missing Values  % Missing data
# Cabin                   687       77.104377
# Age                     177       19.865320
# Embarked                  2        0.224467
# PassengerId               0        0.000000
# Survived                  0        0.000000
# Pclass                    0        0.000000
# Name                      0        0.000000
# Sex                       0        0.000000
# SibSp                     0        0.000000
# Parch                     0        0.000000
# Ticket                    0        0.000000
# Fare                      0        0.000000

# %%
#Statistical Summary

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include= object)
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
#Cabin is unnecessary feature with missing value so we can drop column Cabin.

# %%
df.drop(columns=['Cabin'],inplace = True)

# %%
#How Many Survived?

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('hsv')
f,ax=plt.subplots(1,2,figsize=(14,7))
df['Survived'].value_counts().plot.pie(explode=[0,0.1],textprops ={ 'fontsize':13,'fontweight' :'light'},
                                       autopct='%2.1f%%', ax=ax[0],shadow=True)
ax[0].set_title('Survival Distribution',fontsize=15,fontweight ='light')
ax[0].set_ylabel('')
sns.countplot('Survived',data=df,ax=ax[1])
ax[1].set_title('Survival Count',fontsize=15,fontweight ='light')
ax[1].set_xlabel("Survival Category",fontsize=15,fontweight ='light')
ax[1].set_ylabel("Survival Count", fontsize= 15, fontweight='light')
plt.xticks(fontsize=15,fontweight ='light')
plt.show()

# %%
#*Out of 891 passengers in vessel, only around 342 survived i.e only 38.4% of the passenger survived the crash.*

# %%
#Investigating Gender-wise Survival Rate of Passengers

# %%
df.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('gnuplot_r')
f,ax=plt.subplots(1,2,figsize=(15,7))
df[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
plt.xticks(fontsize=18,fontweight ='bold',rotation=0)
ax[0].set_title('Gender Wise Mean Survival Rate',fontsize=20,fontweight ='bold')

ax[0].set_xlabel("Gender",fontsize=18,fontweight ='bold')
ax[0].set_ylabel("Mean Survival Rate", fontsize= 18, fontweight='bold')
sns.countplot('Sex', hue='Survived', data=df,ax=ax[1])
ax[1].set_title('Gender-wise Survival Rate of Passengers ',fontsize=20,fontweight ='bold')
plt.xticks(fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Gender",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("Survival Count", fontsize= 18, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
#Exploration of Passengers Class Vs Survival

# %%
pd.crosstab(df.Pclass,df.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_6c4c1_row0_col0, #T_6c4c1_row1_col1, #T_6c4c1_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_6c4c1_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_6c4c1_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_6c4c1_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_6c4c1_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_6c4c1_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_6c4c1_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_6c4c1_row3_col0, #T_6c4c1_row3_col1, #T_6c4c1_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6c4c1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_6c4c1_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_6c4c1_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_6c4c1_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c4c1_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_6c4c1_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_6c4c1_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_6c4c1_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_6c4c1_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_6c4c1_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_6c4c1_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_6c4c1_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_6c4c1_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_6c4c1_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_6c4c1_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_6c4c1_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_6c4c1_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_6c4c1_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_6c4c1_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_6c4c1_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('rainbow_r')
f,ax=plt.subplots(1,2,figsize=(15,7))
df['Pclass'].value_counts().plot.bar(ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass', fontsize= 18, fontweight='light')
ax[0].set_ylabel('Passengers Count',fontsize= 15, fontweight='light')
ax[0].set_xlabel('Passengers Class', fontsize= 15, fontweight='light')
sns.countplot('Pclass',hue='Survived', data=df,ax=ax[1])
ax[1].set_title('Pclass:Survived Vs Dead', fontsize= 18, fontweight='light')
ax[1].set_ylabel('Passengers Count',fontsize= 15, fontweight='light')
ax[1].set_xlabel('Passengers Class', fontsize= 15, fontweight='light')
plt.show()

# %%
#Lets check survival rate with Sex and Pclass Together.

# %%
pd.crosstab([df.Sex,df.Survived],df.Pclass, margins= True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_6f364_row0_col0, #T_6f364_row0_col1, #T_6f364_row0_col3, #T_6f364_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_6f364_row0_col2, #T_6f364_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_6f364_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_6f364_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_6f364_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_6f364_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_6f364_row2_col1, #T_6f364_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_6f364_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_6f364_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_6f364_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_6f364_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_6f364_row4_col0, #T_6f364_row4_col1, #T_6f364_row4_col2, #T_6f364_row4_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6f364">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_6f364_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_6f364_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_6f364_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_6f364_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f364_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#       <th id="T_6f364_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_6f364_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_6f364_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_6f364_row0_col2" class="data row0 col2" >72</td>
#       <td id="T_6f364_row0_col3" class="data row0 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_6f364_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_6f364_row1_col0" class="data row1 col0" >91</td>
#       <td id="T_6f364_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_6f364_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_6f364_row1_col3" class="data row1 col3" >233</td>
#     </tr>
#     <tr>
#       <th id="T_6f364_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#       <th id="T_6f364_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_6f364_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_6f364_row2_col1" class="data row2 col1" >91</td>
#       <td id="T_6f364_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_6f364_row2_col3" class="data row2 col3" >468</td>
#     </tr>
#     <tr>
#       <th id="T_6f364_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_6f364_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_6f364_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_6f364_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_6f364_row3_col3" class="data row3 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_6f364_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_6f364_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_6f364_row4_col0" class="data row4 col0" >216</td>
#       <td id="T_6f364_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_6f364_row4_col2" class="data row4 col2" >491</td>
#       <td id="T_6f364_row4_col3" class="data row4 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=df)
plt.show()

# %%
#Age#

# %%
print('Oldest Passenger was of:',df['Age'].max(),'Years')
print('Youngest Passenger was of:',df['Age'].min(),'Years')
print('Average Age on th ship :',df['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on th ship : 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,2,figsize=(15,7))
sns.violinplot('Pclass','Age', hue='Survived', data=df, split=True, ax=ax[0])
ax[0].set_title('Pclass Wise Distribution of Age Vs Survived',fontsize= 20, fontweight='light')
ax[0].set_yticks(range(0,110,10))
ax[0].set_ylabel('Passengers Age',fontsize= 18, fontweight='light')
ax[0].set_xlabel('Passengers Class', fontsize= 18, fontweight='light')
sns.violinplot('Sex','Age', hue='Survived',data=df, split= True, ax=ax[1])
ax[1].set_title('Gender-Wise Age Vs Survived',fontsize= 20, fontweight='light')
ax[1].set_yticks(range(0,110,10))
ax[1].set_ylabel('Passengers Age',fontsize= 18, fontweight='light')
ax[1].set_xlabel('Gender', fontsize= 18, fontweight='light')
plt.show()

# %%
#Handling Missing Values in feature AGE

# %%
df['Initial']=0
for i in df:
    df['Initial']=df.Name.str.extract("([A-Za-z]+)\.") # Extract the Salutations with Regex

# %%
pd.crosstab(df.Initial,df.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_9a46f_row0_col0, #T_9a46f_row0_col1, #T_9a46f_row0_col3, #T_9a46f_row0_col4, #T_9a46f_row0_col5, #T_9a46f_row0_col7, #T_9a46f_row0_col8, #T_9a46f_row0_col12, #T_9a46f_row0_col15, #T_9a46f_row0_col16, #T_9a46f_row1_col2, #T_9a46f_row1_col6, #T_9a46f_row1_col9, #T_9a46f_row1_col10, #T_9a46f_row1_col11, #T_9a46f_row1_col13, #T_9a46f_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_9a46f_row0_col2, #T_9a46f_row0_col6, #T_9a46f_row0_col9, #T_9a46f_row0_col10, #T_9a46f_row0_col11, #T_9a46f_row0_col13, #T_9a46f_row0_col14, #T_9a46f_row1_col0, #T_9a46f_row1_col1, #T_9a46f_row1_col3, #T_9a46f_row1_col4, #T_9a46f_row1_col5, #T_9a46f_row1_col7, #T_9a46f_row1_col8, #T_9a46f_row1_col12, #T_9a46f_row1_col15, #T_9a46f_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9a46f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_9a46f_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_9a46f_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_9a46f_level0_col2" class="col_heading level0 col2" >Countess</th>
#       <th id="T_9a46f_level0_col3" class="col_heading level0 col3" >Don</th>
#       <th id="T_9a46f_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_9a46f_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_9a46f_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_9a46f_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_9a46f_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_9a46f_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_9a46f_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_9a46f_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_9a46f_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_9a46f_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_9a46f_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_9a46f_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_9a46f_level0_col16" class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a46f_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_9a46f_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9a46f_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_9a46f_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_9a46f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9a46f_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_9a46f_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_9a46f_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_9a46f_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_9a46f_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_9a46f_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_9a46f_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_9a46f_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_9a46f_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_9a46f_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_9a46f_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_9a46f_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_9a46f_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9a46f_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_9a46f_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_9a46f_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_9a46f_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_9a46f_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_9a46f_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_9a46f_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_9a46f_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_9a46f_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_9a46f_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_9a46f_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_9a46f_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_9a46f_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_9a46f_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_9a46f_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_9a46f_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_9a46f_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_9a46f_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
df['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],
                      ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
df.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
#Filling NaN Ages

# %%
df.loc[(df.Age.isnull() & (df.Initial)=='Mr'), 'Age'].fillna(32.73,inplace = True)

# %%
df.loc[((df.Age.isnull())&(df.Initial)=='Mr'), 'Age']=32.73
df.loc[((df.Age.isnull())&(df.Initial)=='Mrs'), 'Age']=35.98
df.loc[((df.Age.isnull())&(df.Initial)=='Master'), 'Age']=4.57
df.loc[((df.Age.isnull())&(df.Initial)=='Miss'), 'Age']=21.86
df.loc[((df.Age.isnull())&(df.Initial)=='Other'), 'Age']=45.889

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df[df['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='yellow')
ax[0].set_title('Survived = 0',fontsize= 20, fontweight='light')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
df[df['Survived']==1].Age.plot.hist(ax=ax[1],bins=20,edgecolor='black',color='green')
ax[1].set_title('Survived=1',fontsize= 20, fontweight='light')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
sns.factorplot('Pclass','Survived',col='Initial', data=df)
plt.tight_layout()
plt.show()

# %%
#Analysis Embarked vs Survival

# %%
pd.crosstab([df.Embarked,df.Pclass],[df.Sex,df.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_83c4c_row0_col0, #T_83c4c_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_83c4c_row0_col1 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_83c4c_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_83c4c_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_83c4c_row0_col4, #T_83c4c_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_83c4c_row1_col0, #T_83c4c_row3_col0, #T_83c4c_row3_col1, #T_83c4c_row3_col2, #T_83c4c_row3_col3, #T_83c4c_row3_col4, #T_83c4c_row4_col0, #T_83c4c_row4_col2, #T_83c4c_row4_col3, #T_83c4c_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_83c4c_row1_col1, #T_83c4c_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_83c4c_row1_col3, #T_83c4c_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_83c4c_row2_col0, #T_83c4c_row5_col1 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_83c4c_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_83c4c_row2_col2 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_83c4c_row2_col4, #T_83c4c_row7_col0 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_83c4c_row4_col1 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_83c4c_row5_col0 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_83c4c_row5_col2 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_83c4c_row5_col3 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_83c4c_row5_col4 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_83c4c_row6_col1 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_83c4c_row6_col2 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_83c4c_row6_col3 {
#   background-color: #bede66;
#   color: #000000;
# }
# #T_83c4c_row6_col4 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_83c4c_row7_col1 {
#   background-color: #bdde66;
#   color: #000000;
# }
# #T_83c4c_row7_col2 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_83c4c_row7_col3, #T_83c4c_row8_col1 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_83c4c_row7_col4 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_83c4c_row8_col0 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_83c4c_row8_col2 {
#   background-color: #81c066;
#   color: #000000;
# }
# #T_83c4c_row8_col3 {
#   background-color: #b0d866;
#   color: #000000;
# }
# #T_83c4c_row8_col4 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_83c4c_row9_col0, #T_83c4c_row9_col1, #T_83c4c_row9_col2, #T_83c4c_row9_col3, #T_83c4c_row9_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_83c4c">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Sex</th>
#       <th id="T_83c4c_level0_col0" class="col_heading level0 col0" colspan="2">female</th>
#       <th id="T_83c4c_level0_col2" class="col_heading level0 col2" colspan="2">male</th>
#       <th id="T_83c4c_level0_col4" class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Survived</th>
#       <th id="T_83c4c_level1_col0" class="col_heading level1 col0" >0</th>
#       <th id="T_83c4c_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_83c4c_level1_col2" class="col_heading level1 col2" >0</th>
#       <th id="T_83c4c_level1_col3" class="col_heading level1 col3" >1</th>
#       <th id="T_83c4c_level1_col4" class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embarked</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83c4c_level0_row0" class="row_heading level0 row0" rowspan="3">C</th>
#       <th id="T_83c4c_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_83c4c_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_83c4c_row0_col1" class="data row0 col1" >42</td>
#       <td id="T_83c4c_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_83c4c_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_83c4c_row0_col4" class="data row0 col4" >85</td>
#     </tr>
#     <tr>
#       <th id="T_83c4c_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_83c4c_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_83c4c_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_83c4c_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_83c4c_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_83c4c_row1_col4" class="data row1 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_83c4c_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_83c4c_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_83c4c_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_83c4c_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_83c4c_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_83c4c_row2_col4" class="data row2 col4" >66</td>
#     </tr>
#     <tr>
#       <th id="T_83c4c_level0_row3" class="row_heading level0 row3" rowspan="3">Q</th>
#       <th id="T_83c4c_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_83c4c_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_83c4c_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_83c4c_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_83c4c_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_83c4c_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_83c4c_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_83c4c_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_83c4c_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_83c4c_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_83c4c_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_83c4c_row4_col4" class="data row4 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_83c4c_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_83c4c_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_83c4c_row5_col1" class="data row5 col1" >24</td>
#       <td id="T_83c4c_row5_col2" class="data row5 col2" >36</td>
#       <td id="T_83c4c_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_83c4c_row5_col4" class="data row5 col4" >72</td>
#     </tr>
#     <tr>
#       <th id="T_83c4c_level0_row6" class="row_heading level0 row6" rowspan="3">S</th>
#       <th id="T_83c4c_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_83c4c_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_83c4c_row6_col1" class="data row6 col1" >46</td>
#       <td id="T_83c4c_row6_col2" class="data row6 col2" >51</td>
#       <td id="T_83c4c_row6_col3" class="data row6 col3" >28</td>
#       <td id="T_83c4c_row6_col4" class="data row6 col4" >127</td>
#     </tr>
#     <tr>
#       <th id="T_83c4c_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_83c4c_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_83c4c_row7_col1" class="data row7 col1" >61</td>
#       <td id="T_83c4c_row7_col2" class="data row7 col2" >82</td>
#       <td id="T_83c4c_row7_col3" class="data row7 col3" >15</td>
#       <td id="T_83c4c_row7_col4" class="data row7 col4" >164</td>
#     </tr>
#     <tr>
#       <th id="T_83c4c_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_83c4c_row8_col0" class="data row8 col0" >55</td>
#       <td id="T_83c4c_row8_col1" class="data row8 col1" >33</td>
#       <td id="T_83c4c_row8_col2" class="data row8 col2" >231</td>
#       <td id="T_83c4c_row8_col3" class="data row8 col3" >34</td>
#       <td id="T_83c4c_row8_col4" class="data row8 col4" >353</td>
#     </tr>
#     <tr>
#       <th id="T_83c4c_level0_row9" class="row_heading level0 row9" >All</th>
#       <th id="T_83c4c_level1_row9" class="row_heading level1 row9" ></th>
#       <td id="T_83c4c_row9_col0" class="data row9 col0" >81</td>
#       <t

# %%
#Chances for Survival by Port of Embarkation

# %%
sns.factorplot('Embarked','Survived',data=df)
fig=plt.gcf()
fig.set_size_inches(6,4)
plt.show()

# %%
#The chances for survival for port C is highest around 0.55 while it is lowest for S.

# %%
f,ax=plt.subplots(2,2,figsize=(20,18))
sns.countplot('Embarked',data=df,ax=ax[0,0])
ax[0,0].set_title('No of Passengers Boarded',fontsize= 20, fontweight='light')
ax[0,0].set_ylabel('Passengers Count',fontsize= 18, fontweight='light')
ax[0,0].set_xlabel('Embarked', fontsize= 18, fontweight='light')

sns.countplot('Embarked',hue='Sex',data=df,ax=ax[0,1])
ax[0,1].set_title('Male -Female Split for Embarked',fontsize= 20, fontweight='light')
ax[0,1].set_ylabel('Passengers Count',fontsize= 18, fontweight='light')
ax[0,1].set_xlabel('Embarked', fontsize= 18, fontweight='light')

sns.countplot('Embarked',hue="Survived" ,data=df,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived',fontsize= 20, fontweight='light')
ax[1,0].set_ylabel('Passengers Count',fontsize= 18, fontweight='light')
ax[1,0].set_xlabel('Embarked', fontsize= 18, fontweight='light')

sns.countplot('Embarked',hue='Pclass',data=df,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass',fontsize= 20, fontweight='light')
ax[1,1].set_ylabel('Passengers Count',fontsize= 18, fontweight='light')
ax[1,1].set_xlabel('Embarked', fontsize= 18, fontweight='light')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %%
sns.factorplot('Pclass','Survived', hue='Sex', col='Embarked',data=df)
plt.show()

# %%
#Filling Embarked NaN

# %%
#As we saw that maximum passengers boarded from Port S, we replace NaN with S

# %%
df['Embarked'].fillna('S', inplace=True)

# %%
df.Embarked.isnull().any()
# Out:
# False

# %%
#SibSip vs Survived

# %%
pd.crosstab([df.SibSp],[df.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_ce379_row0_col0 {
#   background-color: #47a366;
#   color: #f1f1f1;
# }
# #T_ce379_row0_col1 {
#   background-color: #62b066;
#   color: #f1f1f1;
# }
# #T_ce379_row0_col2 {
#   background-color: #51a866;
#   color: #f1f1f1;
# }
# #T_ce379_row1_col0 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_ce379_row1_col1 {
#   background-color: #acd666;
#   color: #000000;
# }
# #T_ce379_row1_col2 {
#   background-color: #c5e266;
#   color: #000000;
# }
# #T_ce379_row2_col0, #T_ce379_row4_col0 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_ce379_row2_col1 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_ce379_row2_col2 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_ce379_row3_col0, #T_ce379_row3_col2, #T_ce379_row4_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_ce379_row3_col1, #T_ce379_row4_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_ce379_row5_col0, #T_ce379_row5_col1, #T_ce379_row5_col2, #T_ce379_row6_col0, #T_ce379_row6_col1, #T_ce379_row6_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_ce379_row7_col0, #T_ce379_row7_col1, #T_ce379_row7_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ce379">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_ce379_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_ce379_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_ce379_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce379_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce379_row0_col0" class="data row0 col0" >398</td>
#       <td id="T_ce379_row0_col1" class="data row0 col1" >210</td>
#       <td id="T_ce379_row0_col2" class="data row0 col2" >608</td>
#     </tr>
#     <tr>
#       <th id="T_ce379_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ce379_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_ce379_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_ce379_row1_col2" class="data row1 col2" >209</td>
#     </tr>
#     <tr>
#       <th id="T_ce379_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ce379_row2_col0" class="data row2 col0" >15</td>
#       <td id="T_ce379_row2_col1" class="data row2 col1" >13</td>
#       <td id="T_ce379_row2_col2" class="data row2 col2" >28</td>
#     </tr>
#     <tr>
#       <th id="T_ce379_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ce379_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_ce379_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_ce379_row3_col2" class="data row3 col2" >16</td>
#     </tr>
#     <tr>
#       <th id="T_ce379_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ce379_row4_col0" class="data row4 col0" >15</td>
#       <td id="T_ce379_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_ce379_row4_col2" class="data row4 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_ce379_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ce379_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_ce379_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_ce379_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_ce379_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_ce379_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_ce379_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_ce379_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_ce379_level0_row7" class="row_heading level0 row7" >All</th>
#       <td id="T_ce379_row7_col0" class="data row7 col0" >549</td>
#       <td id="T_ce379_row7_col1" class="data row7 col1" >342</td>
#       <td id="T_ce379_row7_col2" class="data row7 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.barplot('SibSp','Survived', data=df, ax=ax[0])
ax[0].set_title('SibSp Vs Survived',fontsize= 20, fontweight='light')

ax[0].set_ylabel('SibSp',fontsize= 18, fontweight='light')
ax[0].set_xlabel('Survived', fontsize= 18, fontweight='light')

sns.factorplot('SibSp','Survived',data=df, ax=ax[1])
ax[1].set_title('SibSp Vs Survived',fontsize= 20, fontweight='light')
ax[1].set_ylabel('SibSp',fontsize= 18, fontweight='light')
ax[1].set_xlabel('Survived', fontsize= 18, fontweight='light')
plt.tight_layout()
#plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %%
pd.crosstab([df.SibSp],[df.Pclass],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_772e3_row0_col0 {
#   background-color: #5dae66;
#   color: #f1f1f1;
# }
# #T_772e3_row0_col1 {
#   background-color: #59ac66;
#   color: #f1f1f1;
# }
# #T_772e3_row0_col2 {
#   background-color: #49a466;
#   color: #f1f1f1;
# }
# #T_772e3_row0_col3 {
#   background-color: #51a866;
#   color: #f1f1f1;
# }
# #T_772e3_row1_col0 {
#   background-color: #abd566;
#   color: #000000;
# }
# #T_772e3_row1_col1 {
#   background-color: #b3d966;
#   color: #000000;
# }
# #T_772e3_row1_col2 {
#   background-color: #d6eb66;
#   color: #000000;
# }
# #T_772e3_row1_col3 {
#   background-color: #c5e266;
#   color: #000000;
# }
# #T_772e3_row2_col0, #T_772e3_row2_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_772e3_row2_col1 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_772e3_row2_col3, #T_772e3_row4_col2 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_772e3_row3_col0, #T_772e3_row3_col2, #T_772e3_row3_col3, #T_772e3_row4_col3 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_772e3_row3_col1, #T_772e3_row6_col2 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_772e3_row4_col0, #T_772e3_row4_col1, #T_772e3_row5_col0, #T_772e3_row5_col1, #T_772e3_row5_col2, #T_772e3_row5_col3, #T_772e3_row6_col0, #T_772e3_row6_col1, #T_772e3_row6_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_772e3_row7_col0, #T_772e3_row7_col1, #T_772e3_row7_col2, #T_772e3_row7_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_772e3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_772e3_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_772e3_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_772e3_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_772e3_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_772e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_772e3_row0_col0" class="data row0 col0" >137</td>
#       <td id="T_772e3_row0_col1" class="data row0 col1" >120</td>
#       <td id="T_772e3_row0_col2" class="data row0 col2" >351</td>
#       <td id="T_772e3_row0_col3" class="data row0 col3" >608</td>
#     </tr>
#     <tr>
#       <th id="T_772e3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_772e3_row1_col0" class="data row1 col0" >71</td>
#       <td id="T_772e3_row1_col1" class="data row1 col1" >55</td>
#       <td id="T_772e3_row1_col2" class="data row1 col2" >83</td>
#       <td id="T_772e3_row1_col3" class="data row1 col3" >209</td>
#     </tr>
#     <tr>
#       <th id="T_772e3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_772e3_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_772e3_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_772e3_row2_col2" class="data row2 col2" >15</td>
#       <td id="T_772e3_row2_col3" class="data row2 col3" >28</td>
#     </tr>
#     <tr>
#       <th id="T_772e3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_772e3_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_772e3_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_772e3_row3_col2" class="data row3 col2" >12</td>
#       <td id="T_772e3_row3_col3" class="data row3 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_772e3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_772e3_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_772e3_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_772e3_row4_col2" class="data row4 col2" >18</td>
#       <td id="T_772e3_row4_col3" class="data row4 col3" >18</td>
#     </tr>
#     <tr>
#       <th id="T_772e3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_772e3_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_772e3_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_772e3_row5_col2" class="data row5 col2" >5</td>
#       <td id="T_772e3_row5_col3" class="data row5 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_772e3_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_772e3_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_772e3_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_772e3_row6_col2" class="data row6 col2" >7</td>
#       <td id="T_772e3_row6_col3" class="data row6 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_772e3_level0_row7" class="row_heading level0 row7" >All</th>
#       <td id="T_772e3_row7_col0" class="data row7 col0" >216</td>
#       <td id="T_772e3_row7_col1" class="data row7 col1" >184</td>
#       <td id="T_772e3_row7_col2" class="data row7 col2" >491</td>
#       <td id="T_772e3_row7_col3" class="data row7 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Parch Vs Survial

# %%
pd.crosstab([df.Parch],[df.Pclass],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_92f79_row0_col0 {
#   background-color: #3e9e66;
#   color: #f1f1f1;
# }
# #T_92f79_row0_col1 {
#   background-color: #45a266;
#   color: #f1f1f1;
# }
# #T_92f79_row0_col2 {
#   background-color: #399c66;
#   color: #f1f1f1;
# }
# #T_92f79_row0_col3 {
#   background-color: #3d9e66;
#   color: #f1f1f1;
# }
# #T_92f79_row1_col0 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_92f79_row1_col1 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_92f79_row1_col2 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_92f79_row1_col3 {
#   background-color: #deee66;
#   color: #000000;
# }
# #T_92f79_row2_col0 {
#   background-color: #e7f366;
#   color: #000000;
# }
# #T_92f79_row2_col1, #T_92f79_row2_col3 {
#   background-color: #e9f466;
#   color: #000000;
# }
# #T_92f79_row2_col2 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_92f79_row3_col0, #T_92f79_row4_col1, #T_92f79_row4_col3, #T_92f79_row5_col0, #T_92f79_row5_col1, #T_92f79_row6_col0, #T_92f79_row6_col1, #T_92f79_row6_col2, #T_92f79_row6_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_92f79_row3_col1, #T_92f79_row5_col2 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_92f79_row3_col2, #T_92f79_row3_col3, #T_92f79_row4_col0, #T_92f79_row4_col2, #T_92f79_row5_col3 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_92f79_row7_col0, #T_92f79_row7_col1, #T_92f79_row7_col2, #T_92f79_row7_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_92f79">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_92f79_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_92f79_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_92f79_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_92f79_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Parch</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92f79_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_92f79_row0_col0" class="data row0 col0" >163</td>
#       <td id="T_92f79_row0_col1" class="data row0 col1" >134</td>
#       <td id="T_92f79_row0_col2" class="data row0 col2" >381</td>
#       <td id="T_92f79_row0_col3" class="data row0 col3" >678</td>
#     </tr>
#     <tr>
#       <th id="T_92f79_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_92f79_row1_col0" class="data row1 col0" >31</td>
#       <td id="T_92f79_row1_col1" class="data row1 col1" >32</td>
#       <td id="T_92f79_row1_col2" class="data row1 col2" >55</td>
#       <td id="T_92f79_row1_col3" class="data row1 col3" >118</td>
#     </tr>
#     <tr>
#       <th id="T_92f79_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_92f79_row2_col0" class="data row2 col0" >21</td>
#       <td id="T_92f79_row2_col1" class="data row2 col1" >16</td>
#       <td id="T_92f79_row2_col2" class="data row2 col2" >43</td>
#       <td id="T_92f79_row2_col3" class="data row2 col3" >80</td>
#     </tr>
#     <tr>
#       <th id="T_92f79_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_92f79_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_92f79_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_92f79_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_92f79_row3_col3" class="data row3 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_92f79_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_92f79_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_92f79_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_92f79_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_92f79_row4_col3" class="data row4 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_92f79_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_92f79_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_92f79_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_92f79_row5_col2" class="data row5 col2" >5</td>
#       <td id="T_92f79_row5_col3" class="data row5 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_92f79_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_92f79_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_92f79_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_92f79_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_92f79_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_92f79_level0_row7" class="row_heading level0 row7" >All</th>
#       <td id="T_92f79_row7_col0" class="data row7 col0" >216</td>
#       <td id="T_92f79_row7_col1" class="data row7 col1" >184</td>
#       <td id="T_92f79_row7_col2" class="data row7 col2" >491</td>
#       <td id="T_92f79_row7_col3" class="data row7 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.barplot('Parch','Survived', data=df, ax=ax[0])
ax[0].set_title('Parch Vs Survived',fontsize= 20, fontweight='bold')
ax[0].set_ylabel('Survived',fontsize= 18, fontweight='bold')
ax[0].set_xlabel('Parch', fontsize= 18, fontweight='bold')

sns.factorplot('Parch','Survived',data=df, ax=ax[1])
ax[1].set_title('Parch Vs Survived',fontsize= 20, fontweight='bold')
ax[1].set_ylabel('Survived',fontsize= 18, fontweight='bold')
ax[1].set_xlabel('Parch', fontsize= 18, fontweight='bold')

plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %%
#Fare Vs Survival

# %%
print('Highest Fare was :',df['Fare'].max())
print('Highest Fare was :',df['Fare'].min())
print('Average Fare was :',df['Fare'].mean())
# Out:
# Highest Fare was : 512.3292
# Highest Fare was : 0.0
# Average Fare was : 32.2042079685746

# %%
f,ax=plt.subplots(1,3,figsize=(20,7))
sns.distplot(df[df['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1',fontsize= 20, fontweight='light')
ax[0].set_ylabel('Density',fontsize= 18, fontweight='light')
ax[0].set_xlabel('Fares', fontsize= 18, fontweight='light')

sns.distplot(df[df['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2',fontsize= 20, fontweight='light')
ax[1].set_ylabel('Density',fontsize= 18, fontweight='light')
ax[1].set_xlabel('Fares', fontsize= 18, fontweight='light')

sns.distplot(df[df['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3',fontsize= 20, fontweight='light')
ax[2].set_ylabel('Density',fontsize= 18, fontweight='light')
ax[2].set_xlabel('Fares', fontsize= 18, fontweight='light')
plt.show()

# %%
sns.pairplot(data=df, hue='Pclass')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Correlation

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
plt.figure(figsize=(9,6))
sns.heatmap(df.corr(), annot= True, cmap='PiYG',linewidths=0.3)
plt.show()

# %%
#Correlation with Target Variables Survived

# %%
plt.figure(figsize = (12,5))
df.corr()['Survived'].drop(['Survived']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Survived',fontsize=15)
plt.title('Correlation of Survived with Features',fontsize = 18)
plt.show()

# %%
#Outliers Detection and Removal

# %%
# As we have lot of Columns Lets sort Columns by their datatype
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], float64: ['Age', 'Fare'], object: ['Name', 'Sex', 'Ticket', 'Embarked', 'Initial']}

# %%
# Droping unnecessary column for further investigation
df.drop(["PassengerId", "Name" , "Ticket" ],axis=1,inplace=True)

# %%
# As we have lot of Columns Lets sort Columns by their datatype
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['Survived', 'Pclass', 'SibSp', 'Parch'], float64: ['Age', 'Fare'], object: ['Sex', 'Embarked', 'Initial']}

# %%
Numerical_features= ['Survived', 'Pclass', 'SibSp', 'Parch','Age', 'Fare']
Categorical_features = ['Sex', 'Embarked', 'Initial']

# %%
# Identifying the outliers using boxplot in train dataset
plt.figure(figsize=(12,10),facecolor='white')
plotnumber=1
for i in Numerical_features:
    if plotnumber<=10:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(df[i],color='yellow')
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
# Outlier detection 

def detect_outliers(df,n,features):
    """
    Takes a dataframe df of features and returns a list of the indices
    corresponding to the observations containing more than n outliers according
    to the Tukey method.
    """
    outlier_indices = []
    
    # iterate over features(columns)
    for col in features:
        # 1st quartile (25%)
        Q1 = np.percentile(df[col], 25)
        # 3rd quartile (75%)
        Q3 = np.percentile(df[col],75)
        # Interquartile range (IQR)
        IQR = Q3 - Q1
        
        # outlier step
        outlier_step = 1.5 * IQR
        
        # Determine a list of indices of outliers for feature col
        outlier_list_col = df[(df[col] < Q1 - outlier_step) | (df[col] > Q3 + outlier_step )].index
        
        # append the found outlier indices for col to the list of outlier indices 
        outlier_indices.extend(outlier_list_col)
        
    # select observations containing more than 2 outliers
    outlier_indices = Counter(outlier_indices)        
    multiple_outliers = list( k for k, v in outlier_indices.items() if v > n )
    
    return multiple_outliers

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked Initial
# 0         0       3    male  22.0      1      0   7.2500        S      Mr
# 1         1       1  female  38.0      1      0  71.2833        C     Mrs
# 2         1       3  female  26.0      0      0   7.9250        S    Miss
# 3         1       1  female  35.0      1      0  53.1000        S     Mrs
# 4         0       3    male  35.0      0      0   8.0500        S      Mr

# %%
# detect outliers from Age, SibSp , Parch and Fare
from collections import Counter
Outliers_to_drop = detect_outliers(df,2,["Age","SibSp","Parch","Fare"])

# %%
# Drop outliers
df = df.drop(Outliers_to_drop, axis = 0).reset_index(drop=True)

# %%
df.shape

# %%
# Filling missing value of Age 

## Fill Age with the median age of similar rows according to Pclass, Parch and SibSp
# Index of NaN age rows
index_NaN_age = list(df["Age"][df["Age"].isnull()].index)

for i in index_NaN_age :
    age_med = df["Age"].median()
    age_pred = df["Age"][((df['SibSp'] == df.iloc[i]["SibSp"]) & (df['Parch'] == df.iloc[i]["Parch"]) & (df['Pclass'] == df.iloc[i]["Pclass"]))].median()
    if not np.isnan(age_pred) :
        df['Age'].iloc[i] = age_pred
    else :
        df['Age'].iloc[i] = age_med

# %%
#Encoding Categorical Features

# %%
# Using Label encoder for transforming Categorical data
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Categorical_features:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Initial
# 0         0       3    1  22.0      1      0   7.2500         2        2
# 1         1       1    0  38.0      1      0  71.2833         0        3
# 2         1       3    0  26.0      0      0   7.9250         2        1
# 3         1       1    0  35.0      1      0  53.1000         2        3
# 4         0       3    1  35.0      0      0   8.0500         2        2

# %%
#Standard Scaler

# %%
# Splitting data in target and dependent feature
X = df.drop(['Survived'], axis =1)
Y = df['Survived']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
#Machine Learning Model Building

# %%
#Importing Machine learning Model library
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=67, test_size=.25)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (660, 8)
# Training target vector size: (660,)
# Test feature matrix size: (221, 8)
# Test target vector size: (221,)

# %%
#Finding best Random state

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
maxAccu=0
maxRS=0
for i in range(50,300):
    X_train,X_test,Y_train,Y_test = train_test_split(X_scale,Y,test_size = 0.3, random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(X_train,Y_train)
    y_pred=log_reg.predict(X_test)
    acc=accuracy_score(Y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu ,'on Random_state', maxRS)
# Out:
# Best accuracy is 0.8566037735849057 on Random_state 69

# %%
#Logistics Regression

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=69, test_size=.25)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.8687782805429864
#
#
# Confusion matrix of Logistics Regression :
#  [[120   9]
#  [ 20  72]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89       129
#            1       0.89      0.78      0.83        92
#
#     accuracy                           0.87       221
#    macro avg       0.87      0.86      0.86       221
# weighted avg       0.87      0.87      0.87       221

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(log_reg, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', log_reg, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score LogisticRegression() :
#
# CVScore : [0.77966102 0.79545455 0.77272727 0.78977273 0.82386364]
# Mean CV Score : 0.7922958397534668
# Std deviation : 0.017637669142336193

# %%
#Decision Tree Classifier

# %%
dtc=DecisionTreeClassifier()
dtc.fit(X_train,Y_train)
y_pred=dtc.predict(X_test)
print('\033[1m'+'Decision Tree Classifier Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Decision Tree Classifier :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Decision Tree Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Decision Tree Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Decision Tree Classifier Evaluation
#
#
# Accuracy Score of Decision Tree Classifier : 0.8009049773755657
#
#
# Confusion matrix of Decision Tree Classifier :
#  [[107  22]
#  [ 22  70]]
#
#
# classification Report of Decision Tree Classifier
#                precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83       129
#            1       0.76      0.76      0.76        92
#
#     accuracy                           0.80       221
#    macro avg       0.80      0.80      0.80       221
# weighted avg       0.80      0.80      0.80       221

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(dtc, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', dtc, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score DecisionTreeClassifier() :
#
# CVScore : [0.74576271 0.78977273 0.83522727 0.75568182 0.82386364]
# Mean CV Score : 0.7900616332819722
# Std deviation : 0.035572348785533704

# %%
#Random Forest Classifier

# %%
rfc=RandomForestClassifier()
rfc.fit(X_train,Y_train)
y_pred=rfc.predict(X_test)
print('\033[1m'+'Random Forest Classifier'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Random Forest Classifier :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Random Forest Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Random Forest Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Random Forest Classifier
#
#
# Accuracy Score of Random Forest Classifier : 0.8552036199095022
#
#
# Confusion matrix of Random Forest Classifier :
#  [[113  16]
#  [ 16  76]]
#
#
# classification Report of Random Forest Classifier
#                precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88       129
#            1       0.83      0.83      0.83        92
#
#     accuracy                           0.86       221
#    macro avg       0.85      0.85      0.85       221
# weighted avg       0.86      0.86      0.86       221

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(rfc, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', rfc, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score RandomForestClassifier() :
#
# CVScore : [0.81355932 0.80113636 0.84659091 0.76704545 0.84090909]
# Mean CV Score : 0.8138482280431434
# Std deviation : 0.028832440173179326

# %%
#AdaBoost Classifier

# %%
adbc=AdaBoostClassifier()
adbc.fit(X_train,Y_train)
y_pred=adbc.predict(X_test)
print('\033[1m'+'AdaBoost Classifier Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of AdaBoost Classifier :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of AdaBoost Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of AdaBoost Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# AdaBoost Classifier Evaluation
#
#
# Accuracy Score of AdaBoost Classifier : 0.8642533936651584
#
#
# Confusion matrix of AdaBoost Classifier :
#  [[117  12]
#  [ 18  74]]
#
#
# classification Report of AdaBoost Classifier
#                precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89       129
#            1       0.86      0.80      0.83        92
#
#     accuracy                           0.86       221
#    macro avg       0.86      0.86      0.86       221
# weighted avg       0.86      0.86      0.86       221

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(adbc, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score',adbc, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score AdaBoostClassifier() :
#
# CVScore : [0.78531073 0.8125     0.81818182 0.80113636 0.85795455]
# Mean CV Score : 0.8150166923472009
# Std deviation : 0.024228571770988406

# %%
#Gradient Boosting Classifier

# %%
grad_bc=GradientBoostingClassifier()
grad_bc.fit(X_train,Y_train)
y_pred=grad_bc.predict(X_test)
print('\033[1m'+'Gradient Boosting Classifier Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Gradient Boosting Classifier :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Gradient Boosting Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Gradient Boosting Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Gradient Boosting Classifier Evaluation
#
#
# Accuracy Score of Gradient Boosting Classifier : 0.832579185520362
#
#
# Confusion matrix of Gradient Boosting Classifier :
#  [[117  12]
#  [ 25  67]]
#
#
# classification Report of Gradient Boosting Classifier
#                precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86       129
#            1       0.85      0.73      0.78        92
#
#     accuracy                           0.83       221
#    macro avg       0.84      0.82      0.82       221
# weighted avg       0.83      0.83      0.83       221

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(grad_bc, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', grad_bc, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score GradientBoostingClassifier() :
#
# CVScore : [0.83050847 0.8125     0.85227273 0.79545455 0.85795455]
# Mean CV Score : 0.8297380585516179
# Std deviation : 0.023567286230155634

# %%
#Hyper Parameter Tuning : GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = [{'fit_intercept': [True, False], #default: True
            'penalty': ['l1','l2'],
            'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'], #default: lbfgs
            'random_state': [69]
             }]

# %%
GCV = GridSearchCV(LogisticRegression(),parameter,verbose=5)
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.826 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.773 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.765 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.705 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.742 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.818 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.773 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.765 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.705 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.742 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.826 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.773 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.765 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.712 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.742 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.826 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.773 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.765 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.712 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.742 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.826 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.773 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.765 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.705 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.742 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.826 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.773 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.765 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.712 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.742 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.826 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.773 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.765 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.712 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.742 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.841 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.765 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.765 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.689 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.720 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.841 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.765 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.765 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.689 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.727 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.841 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.765 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.773 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.689 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.727 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.841 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.765 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.773 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.689 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.727 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.841 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.765 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.773 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.689 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.727 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.841 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.765 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.773 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.689 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.727 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.841 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.765 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.773 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.689 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.727 total time=   0.0s
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid=[{'fit_intercept': [True, False],
#                           'penalty': ['l1', 'l2'], 'random_state': [69],
#                           'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                      'saga']}],
#              verbose=5)

# %%
GCV.best_params_
# Out:
# {'fit_intercept': True,
#  'penalty': 'l2',
#  'random_state': 69,
#  'solver': 'newton-cg'}

# %%
#Final Model
Final_mod = LogisticRegression(fit_intercept =True,penalty= "l2",solver='newton-cg',random_state= 69)
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\033[1m'+'Final Random Forest Classifier Model'+'\033[0m')
print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Random Forest Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'Classification Report of Random Forest Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Final Random Forest Classifier Model
# Accuracy Score :
#  0.8687782805429864
#
#
# Confusion matrix of Random Forest Classifier :
#  [[120   9]
#  [ 20  72]]
#
#
# Classification Report of Random Forest Classifier
#                precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89       129
#            1       0.89      0.78      0.83        92
#
#     accuracy                           0.87       221
#    macro avg       0.87      0.86      0.86       221
# weighted avg       0.87      0.87      0.87       221

# %%
# Lets plot confusion matrix for  FinalModel
Matrix = confusion_matrix(Y_test, y_pred)

x_labels = ["NO","YES"]
y_labels = ["NO","YES"]

fig , ax = plt.subplots(figsize=(5,5))
sns.heatmap(Matrix, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, 
            cmap="plasma", xticklabels = x_labels, yticklabels = y_labels)

plt.xlabel("Predicted Label",fontsize=14,fontweight='bold')
plt.ylabel("True Label",fontsize=14,fontweight='bold')
plt.title('Confusion Matrix for Final Model',fontsize=20,fontweight='bold')
plt.show()

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import plot_roc_curve
disp = plot_roc_curve(Final_mod,X_test,Y_test)   
plt.legend(prop={'size':11}, loc='lower right')
plt.title('AOC ROC Curve of Final Model',fontsize=20,fontweight='bold')
plt.show()
auc_score = roc_auc_score(Y_test, Final_mod.predict(X_test))
print('\033[1m'+'Auc Score :'+'\033[0m\n',auc_score)
# Out:
# Auc Score :
#  0.8564206268958544

# %%
#Predicting the Final Model

# %%
prediction = Final_mod.predict(X_test)

# %%
Actual = np.array(Y_test)
df_Pred = pd.DataFrame()
df_Pred["Predicted Values"] = prediction
df_Pred["Actual Values"] = Actual
df_Pred.head()
# Out:
#    Predicted Values  Actual Values
# 0                 1              1
# 1                 0              0
# 2                 1              1
# 3                 1              1
# 4                 0              0
